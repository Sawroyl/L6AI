# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)

# %%
from PIL import Image

# %%
image_colored = Image.open("/content/drive/MyDrive/AI And ML/lenna_image.png")

# %%
print("Format:", image_colored.format)
print("Mode:", image_colored.mode)
print("Size:", image_colored.size)
# Out:
# Format: PNG
# Mode: RGBA
# Size: (366, 357)

# %%
image_colored = image_colored.convert("RGB")

# %%
print(image_colored.mode)
# Out:
# RGB

# %%
image_grayed = image_colored.convert('L')
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %% [markdown]
# GrayScale Image

# %%
image_grayed = image_colored.convert('L')

# %%
print(image_grayed.size)
# Out:
# (366, 357)

# %%
width, height = image_grayed.size
channels = len(image_grayed.getbands())

print(f"Image shape (gray): ({height}, {width}, {channels})")

image_size_grayed = width * height * 1
print(f"Image size (gray): {image_size_grayed}")
# Out:
# Image shape (gray): (357, 366, 1)
# Image size (gray): 130662

# %%
width, height = image_colored.size
channels = len(image_colored.getbands())

print(f"Image shape (colored): ({height}, {width}, {channels})")

image_size_colored = width * height * 3
print(f"Image size (colored): {image_size_colored}")
# Out:
# Image shape (colored): (357, 366, 4)
# Image size (colored): 391986

# %% [markdown]
# Converting into numpy

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (357, 366, 4)

# %%
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (357, 366)

# %% [markdown]
# Accessing individual channels

# %%
red_channel = image_array_colored[: , :, 0] #Red channel only one channel makes grayscale
print(red_channel)
display(red_channel)
# Out:
# [[225 224 226 ...  92  90  91]
#  [225 224 224 ...  91  90  91]
#  [223 223 224 ...  93  91  91]
#  ...
#  [ 88  92  95 ... 148 162 175]
#  [ 88  92  96 ... 154 168 177]
#  [254 254 254 ... 255 255 255]]
# array([[225, 224, 226, ...,  92,  90,  91],
#        [225, 224, 224, ...,  91,  90,  91],
#        [223, 223, 224, ...,  93,  91,  91],
#        ...,
#        [ 88,  92,  95, ..., 148, 162, 175],
#        [ 88,  92,  96, ..., 154, 168, 177],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = image_array_colored[: , :, 1] #Red channel
print(red_channel)
display(red_channel)
# Out:
# [[127 130 130 ...  25  23  17]
#  [130 128 130 ...  22  22  20]
#  [128 133 129 ...  25  22  17]
#  ...
#  [ 23  22  26 ...  57  68  66]
#  [ 26  27  26 ...  63  71  66]
#  [254 254 254 ... 255 255 255]]
# array([[127, 130, 130, ...,  25,  23,  17],
#        [130, 128, 130, ...,  22,  22,  20],
#        [128, 133, 129, ...,  25,  22,  17],
#        ...,
#        [ 23,  22,  26, ...,  57,  68,  66],
#        [ 26,  27,  26, ...,  63,  71,  66],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = image_array_colored[: , :, 2] #Red channel
print(red_channel)
display(red_channel)
# Out:
# [[110 106 105 ...  64  62  56]
#  [110 104 114 ...  64  61  63]
#  [105 114 111 ...  67  65  61]
#  ...
#  [ 58  58  60 ...  78  84  78]
#  [ 58  61  61 ...  83  85  77]
#  [254 254 254 ... 255 255 255]]
# array([[110, 106, 105, ...,  64,  62,  56],
#        [110, 104, 114, ...,  64,  61,  63],
#        [105, 114, 111, ...,  67,  65,  61],
#        ...,
#        [ 58,  58,  60, ...,  78,  84,  78],
#        [ 58,  61,  61, ...,  83,  85,  77],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = image_array_colored.copy()
red_channel[:, :, 1] = 0 #if 1, it shows red
red_channel[:, :, 2] = 0
print(red_channel)
# Out:
# [[[225   0   0 255]
#   [224   0   0 255]
#   [226   0   0 255]
#   ...
#   [ 92   0   0 255]
#   [ 90   0   0 255]
#   [ 91   0   0 255]]
#
#  [[225   0   0 255]
#   [224   0   0 255]
#   [224   0   0 255]
#   ...
#   [ 91   0   0 255]
#   [ 90   0   0 255]
#   [ 91   0   0 255]]
#
#  [[223   0   0 255]
#   [223   0   0 255]
#   [224   0   0 255]
#   ...
#   [ 93   0   0 255]
#   [ 91   0   0 255]
#   [ 91   0   0 255]]
#
#  ...
#
#  [[ 88   0   0 255]
#   [ 92   0   0 255]
#   [ 95   0   0 255]
#   ...
#   [148   0   0 255]
#   [162   0   0 255]
#   [175   0   0 255]]
#
#  [[ 88   0   0 255]
#   [ 92   0   0 255]
#   [ 96   0   0 255]
#   ...
#   [154   0   0 255]
#   [168   0   0 255]
#   [177   0   0 255]]
#
#  [[254   0   0 255]
#   [254   0   0 255]
#   [254   0   0 255]
#   ...
#   [255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]]]

# %%
display(red_channel)
# Out:
# array([[[225,   0,   0, 255],
#         [224,   0,   0, 255],
#         [226,   0,   0, 255],
#         ...,
#         [ 92,   0,   0, 255],
#         [ 90,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        [[225,   0,   0, 255],
#         [224,   0,   0, 255],
#         [224,   0,   0, 255],
#         ...,
#         [ 91,   0,   0, 255],
#         [ 90,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        [[223,   0,   0, 255],
#         [223,   0,   0, 255],
#         [224,   0,   0, 255],
#         ...,
#         [ 93,   0,   0, 255],
#         [ 91,   0,   0, 255],
#         [ 91,   0,   0, 255]],
#
#        ...,
#
#        [[ 88,   0,   0, 255],
#         [ 92,   0,   0, 255],
#         [ 95,   0,   0, 255],
#         ...,
#         [148,   0,   0, 255],
#         [162,   0,   0, 255],
#         [175,   0,   0, 255]],
#
#        [[ 88,   0,   0, 255],
#         [ 92,   0,   0, 255],
#         [ 96,   0,   0, 255],
#         ...,
#         [154,   0,   0, 255],
#         [168,   0,   0, 255],
#         [177,   0,   0, 255]],
#
#        [[254,   0,   0, 255],
#         [254,   0,   0, 255],
#         [254,   0,   0, 255],
#         ...,
#         [255,   0,   0, 255],
#         [255,   0,   0, 255],
#         [255,   0,   0, 255]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(red_channel)

# %%
green_channel = image_array_colored.copy()
green_channel[:, :, 0] = 0
green_channel[:, :, 2] = 0
print(green_channel)
plt.imshow(green_channel)
# Out:
# [[[  0 127   0 255]
#   [  0 130   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  23   0 255]
#   [  0  17   0 255]]
#
#  [[  0 130   0 255]
#   [  0 128   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  22   0 255]
#   [  0  22   0 255]
#   [  0  20   0 255]]
#
#  [[  0 128   0 255]
#   [  0 133   0 255]
#   [  0 129   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  22   0 255]
#   [  0  17   0 255]]
#
#  ...
#
#  [[  0  23   0 255]
#   [  0  22   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  57   0 255]
#   [  0  68   0 255]
#   [  0  66   0 255]]
#
#  [[  0  26   0 255]
#   [  0  27   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  63   0 255]
#   [  0  71   0 255]
#   [  0  66   0 255]]
#
#  [[  0 254   0 255]
#   [  0 254   0 255]
#   [  0 254   0 255]
#   ...
#   [  0 255   0 255]
#   [  0 255   0 255]
#   [  0 255   0 255]]]

# %%
blue_channel = image_array_colored.copy()
blue_channel[:, :, 0] = 0
blue_channel[:, :, 2] = 0
print(blue_channel)
display(blue_channel)
plt.imshow(blue_channel)
# Out:
# [[[  0 127   0 255]
#   [  0 130   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  23   0 255]
#   [  0  17   0 255]]
#
#  [[  0 130   0 255]
#   [  0 128   0 255]
#   [  0 130   0 255]
#   ...
#   [  0  22   0 255]
#   [  0  22   0 255]
#   [  0  20   0 255]]
#
#  [[  0 128   0 255]
#   [  0 133   0 255]
#   [  0 129   0 255]
#   ...
#   [  0  25   0 255]
#   [  0  22   0 255]
#   [  0  17   0 255]]
#
#  ...
#
#  [[  0  23   0 255]
#   [  0  22   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  57   0 255]
#   [  0  68   0 255]
#   [  0  66   0 255]]
#
#  [[  0  26   0 255]
#   [  0  27   0 255]
#   [  0  26   0 255]
#   ...
#   [  0  63   0 255]
#   [  0  71   0 255]
#   [  0  66   0 255]]
#
#  [[  0 254   0 255]
#   [  0 254   0 255]
#   [  0 254   0 255]
#   ...
#   [  0 255   0 255]
#   [  0 255   0 255]
#   [  0 255   0 255]]]
# array([[[  0, 127,   0, 255],
#         [  0, 130,   0, 255],
#         [  0, 130,   0, 255],
#         ...,
#         [  0,  25,   0, 255],
#         [  0,  23,   0, 255],
#         [  0,  17,   0, 255]],
#
#        [[  0, 130,   0, 255],
#         [  0, 128,   0, 255],
#         [  0, 130,   0, 255],
#         ...,
#         [  0,  22,   0, 255],
#         [  0,  22,   0, 255],
#         [  0,  20,   0, 255]],
#
#        [[  0, 128,   0, 255],
#         [  0, 133,   0, 255],
#         [  0, 129,   0, 255],
#         ...,
#         [  0,  25,   0, 255],
#         [  0,  22,   0, 255],
#         [  0,  17,   0, 255]],
#
#        ...,
#
#        [[  0,  23,   0, 255],
#         [  0,  22,   0, 255],
#         [  0,  26,   0, 255],
#         ...,
#         [  0,  57,   0, 255],
#         [  0,  68,   0, 255],
#         [  0,  66,   0, 255]],
#
#        [[  0,  26,   0, 255],
#         [  0,  27,   0, 255],
#         [  0,  26,   0, 255],
#         ...,
#         [  0,  63,   0, 255],
#         [  0,  71,   0, 255],
#         [  0,  66,   0, 255]],
#
#        [[  0, 254,   0, 255],
#         [  0, 254,   0, 255],
#         [  0, 254,   0, 255],
#         ...,
#         [  0, 255,   0, 255],
#         [  0, 255,   0, 255],
#         [  0, 255,   0, 255]]], dtype=uint8)

# %% [markdown]
# Extracting Colored Channels Using PIL

# %%
image_colored = Image.open("/content/drive/MyDrive/AI And ML/lenna_image.png")
r, g, b, a = image_colored.split()
display(r)
display(g)
display(b)
display(a)
# Out:
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>

# %%
len(image_colored.split())
# Out:
# 4

# %% [markdown]
# Extracting Sub Images from an Image Array

# %%
row_100 = image_array_colored[100, :, :]
print(row_100)
# Out:
# [[169  63  76 255]
#  [166  65  75 255]
#  [170  64  76 255]
#  ...
#  [210 132 122 255]
#  [209 133 116 255]
#  [208 134 126 255]]

# %%
col_50 = image_array_colored[:, 50, :]
print(col_50)
# Out:
# [[160  61  82 255]
#  [163  63  82 255]
#  [166  61  74 255]
#  ...
#  [ 82  19  67 255]
#  [ 79  18  66 255]
#  [254 254 254 255]]

# %% [markdown]
# Extracting Sub Images(cropping) Using PIL

# %%
left = 100
upper = 50
right = 200
lower = 150
cropped_image = image_colored.crop((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %% [markdown]
# Saving Numpy to Image

# %%
image_array = np.zeros ((100, 100, 3), dtype=np.uint8)
image_from_array = Image.fromarray(image_array)
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_from_array.save = ("sample_data/output_image.jpg")

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("/content/drive/MyDrive/AI And ML/camera_man.jpg").convert('L')
image_array = np.array(image)
print(image_array.shape)

height, width = image_array.shape[0], image_array.shape[1]

#data= image_array.reshape (height, width)
data = image_array.copy()

plt.imshow(image_array, cmap='gray')
plt.show()
# Out:
# (325, 220)

# %%
#Compute the mean of each column (feature)
mean = np.mean(data)
#Subtract mean to center the data
centered_data = data - mean
centered_data = centered_data

# %%
centered_data.shape
# Out:
# (325, 220)

# %%
cov_matrix = np.cov(centered_data, rowvar=False)

# %%
cov_matrix.shape
# Out:
# (220, 220)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np.sum (eigenvalues)
plt.plot (np.cumsum(explained_variance_ratio))
plt.title("Cumulative Explained Variance")
plt.xlabel ("Number of Components")
plt.ylabel ("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# %%
k = 40  #Choose k principal components
##Compress and save storage
components= eigenvectors [:,: k]

# %%
compressed_data = np.dot(centered_data, components)

# %%
decompressed_data = np.dot(compressed_data, components.T) + mean

# %%
plt.figure(figsize=(12, 6))
#Original Image
plt.subplot(1, 3, 1)
plt.imshow(image_array, cmap='gray')
plt.title("Original Image")
plt.axis('off')
#Compressed Representation
plt.subplot(1, 3, 2)
plt.imshow(compressed_data, cmap='gray', aspect="auto")
plt.title(f"Compressed Image (k={k})")
plt.axis('off')
#Decompressed Image
plt.subplot(1, 3, 3)
plt.imshow(decompressed_data, cmap='gray')
plt.title("Decompressed Image")
# Out:
# Text(0.5, 1.0, 'Decompressed Image')
